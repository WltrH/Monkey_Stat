# %%
#Importation des bibliothèques
import pandas as pd
import seaborn as sb
import matplotlib.pyplot as plt

# importation de la librairie stats
from scipy import stats

# %%
# importation du fichier csv
data = pd.read_csv("results.csv")

# %%
data.head()
# Out:
#                         _id isPb    wpm    acc  rawWpm  consistency  \
# 0  6725e74850538de2c29b687f  NaN  64.62  94.97   73.92        68.18
# 1  6725345950538de2c295bebc  NaN  65.04  92.45   67.29        72.18
# 2  672533ec50538de2c295b93f  NaN  70.73  97.18   70.73        66.23
# 3  672533b950538de2c295b6e4  NaN  68.04  98.69   68.04        67.79
# 4  6725319350538de2c2959d2e  NaN  71.98  98.54   77.04        76.31
#
#    charStats   mode  mode2  quoteLength  ...  punctuation  numbers  language  \
# 0  139;3;2;0  words     25           -1  ...        False    False    french
# 1  144;1;0;0  words     25           -1  ...        False    False    french
# 2  138;0;0;0  words     25           -1  ...        False    False    french
# 3  151;0;0;0  words     25           -1  ...        False    False    french
# 4  128;1;0;0  words     25           -1  ...        False    False    french
#
#    funbox  difficulty  lazyMode blindMode bailedOut tags      timestamp
# 0    none      normal     False     False     False  NaN  1730537288000
# 1    none      normal     False     False     False  NaN  1730491481000
# 2    none      normal     False     False     False  NaN  1730491372000
# 3    none      normal     False     False     False  NaN  1730491321000
# 4    none      normal     False     False     False  NaN  1730490771000
#
# [5 rows x 24 columns]

# %%
# connexion API
import requests

# URL de l'API
url = "https://api.example.com/data"

# Paramètres de la requête
params = {
    "api_key": "votre_cle_api",
    "param1": "valeur1",
    "param2": "valeur2"
}

# Envoi de la requête GET à l'API
response = requests.get(url, params=params)

# Vérification du statut de la réponse
if response.status_code == 200:
    # Conversion de la réponse en JSON
    api_data = response.json()
    print("Connexion à l'API réussie")
else:
    print(f"Erreur lors de la connexion à l'API: {response.status_code}")
